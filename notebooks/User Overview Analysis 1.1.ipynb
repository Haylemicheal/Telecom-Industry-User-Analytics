# %%
import sys, os
sys.path.append(os.path.abspath(os.path.join('..')))

# %%
from scripts.dataloader import DataLoader
from scripts.data_understanding import DataUnderstanding
from scripts.visualization import Visualization

# %% [markdown]
# ## Read the clean csv file

# %%
dl = DataLoader('../data', 'clean_data.csv')
df = dl.read_csv()

# %%
du = DataUnderstanding(df)

# %% [markdown]
# ## Pick sample data out

# %%
df.shape
# Out:
# (150001, 45)

# %%
du.pick_data(10)
# Out:
#       Bearer Id            Start  Start ms              End  End ms  \
# 0  1.311448e+19   4/4/2019 12:01     770.0  4/25/2019 14:35   662.0
# 1  1.311448e+19   4/9/2019 13:04     235.0   4/25/2019 8:15   606.0
# 2  1.311448e+19   4/9/2019 17:42       1.0  4/25/2019 11:58   652.0
# 3  1.311448e+19   4/10/2019 0:31     486.0   4/25/2019 7:36   171.0
# 4  1.311448e+19  4/12/2019 20:10     565.0  4/25/2019 10:40   954.0
# 5  1.311448e+19  4/12/2019 21:37     439.0   4/25/2019 8:08   553.0
# 6  1.311448e+19   4/13/2019 8:41     612.0   4/25/2019 8:16   168.0
# 7  1.304243e+19   4/14/2019 2:11     592.0   4/25/2019 2:26   512.0
# 8  1.311448e+19  4/14/2019 12:48     121.0  4/25/2019 10:22   960.0
# 9  1.304243e+19   4/15/2019 0:32       0.0   4/25/2019 0:40   284.0
#
#    Dur. (ms)          IMSI  MSISDN/Number          IMEI  \
# 0  1823652.0  2.082014e+14   3.366496e+10  3.552121e+13
# 1  1365104.0  2.082019e+14   3.368185e+10  3.579401e+13
# 2  1361762.0  2.082003e+14   3.376063e+10  3.528151e+13
# 3  1321509.0  2.082014e+14   3.375034e+10  3.535661e+13
# 4  1089009.0  2.082014e+14   3.369980e+10  3.540701e+13
# 5  1074638.0  2.082014e+14   3.366819e+10  3.529841e+13
# 6  1035261.0  2.082014e+14   3.366537e+10  8.676270e+13
# 7   951292.0  2.082010e+14   3.376349e+10  8.654640e+13
# 8   941634.0  2.082014e+14   3.369874e+10  3.556241e+13
# 9   864482.0  2.082003e+14   3.365922e+10  3.557311e+13
#
#       Last Location Name  ...  Youtube DL (Bytes)  Youtube UL (Bytes)  \
# 0  9.16456699548519E+015  ...          15854611.0           2501332.0
# 1                L77566A  ...          20247395.0          19111729.0
# 2                D42335A  ...          19725661.0          14699576.0
# 3                T21824A  ...          21388122.0          15146643.0
# 4                D88865A  ...          15259380.0          18962873.0
# 5                T89132C  ...          21332918.0           2611113.0
# 6  9.16456701058919E+015  ...           7234465.0           1886295.0
# 7   CELL_208_20_520025_1  ...          12189786.0          19735183.0
# 8                T42084A  ...          18436641.0          10860867.0
# 9                L20434C  ...          16338345.0           6573194.0
#
#    Netflix DL (Bytes)  Netflix UL (Bytes)  Gaming DL (Bytes)  \
# 0           8198936.0           9656251.0        278082303.0
# 1          18338413.0          17227132.0        608750074.0
# 2          17587794.0           6163408.0        229584621.0
# 3          13994646.0           1097942.0        799538153.0
# 4          17124581.0            415218.0        527707248.0
# 5           7345361.0           6536448.0        710293538.0
# 6          13231006.0          17981760.0         44796223.0
# 7           6858496.0          12075206.0        748906189.0
# 8          10587264.0           8467177.0        821671285.0
# 9          12211149.0            974201.0        811355188.0
#
#    Gaming UL (Bytes)  Other DL (Bytes)  Other UL (Bytes)  Total UL (Bytes)  \
# 0         14344150.0       171744450.0         8814393.0        36749741.0
# 1          1170709.0       526904238.0        15055145.0        53800391.0
# 2           395630.0       410692588.0         4215763.0        27883638.0
# 3         10849722.0       749039933.0        12797283.0        43324218.0
# 4          3529801.0       550709500.0        13910322.0        38542814.0
# 5         13167974.0       654978277.0         4436057.0        30307754.0
# 6         14084934.0       803653557.0        10649768.0        47925246.0
# 7         16149622.0       537601820.0         7714657.0        58813016.0
# 8          6548349.0       172920486.0        14749031.0        42363146.0
# 9          1591237.0        64856042.0        12815208.0        22417975.0
#
#    Total DL (Bytes)
# 0       308879636.0
# 1       653384965.0
# 2       279807335.0
# 3       846028530.0
# 4       569138589.0
# 5       754452212.0
# 6        70562047.0
# 7       775350343.0
# 8       861612261.0
# 9       850570347.0
#
# [10 rows x 45 columns]

# %%
df.columns
# Out:
# Index(['Bearer Id', 'Start', 'Start ms', 'End', 'End ms', 'Dur. (ms)', 'IMSI',
#        'MSISDN/Number', 'IMEI', 'Last Location Name', 'Avg RTT DL (ms)',
#        'Avg RTT UL (ms)', 'Avg Bearer TP DL (kbps)', 'Avg Bearer TP UL (kbps)',
#        'DL TP < 50 Kbps (%)', '50 Kbps < DL TP < 250 Kbps (%)',
#        '250 Kbps < DL TP < 1 Mbps (%)', 'DL TP > 1 Mbps (%)',
#        'UL TP < 10 Kbps (%)', '10 Kbps < UL TP < 50 Kbps (%)',
#        '50 Kbps < UL TP < 300 Kbps (%)', 'UL TP > 300 Kbps (%)',
#        'Activity Duration DL (ms)', 'Activity Duration UL (ms)', 'Dur. (ms).1',
#        'Handset Manufacturer', 'Handset Type', 'Nb of sec with Vol DL < 6250B',
#        'Nb of sec with Vol UL < 1250B', 'Social Media DL (Bytes)',
#        'Social Media UL (Bytes)', 'Google DL (Bytes)', 'Google UL (Bytes)',
#        'Email DL (Bytes)', 'Email UL (Bytes)', 'Youtube DL (Bytes)',
#        'Youtube UL (Bytes)', 'Netflix DL (Bytes)', 'Netflix UL (Bytes)',
#        'Gaming DL (Bytes)', 'Gaming UL (Bytes)', 'Other DL (Bytes)',
#        'Other UL (Bytes)', 'Total UL (Bytes)', 'Total DL (Bytes)'],
#       dtype='object')

# %% [markdown]
# ## Top 10 handsets used by the customers

# %%
top10handsets = df['Handset Type'].value_counts().head(10)
top10handsets
# Out:
# Huawei B528S-23A                20324
# Apple iPhone 6S (A1688)          9419
# Apple iPhone 6 (A1586)           9023
# undefined                        8987
# Apple iPhone 7 (A1778)           6326
# Apple iPhone Se (A1723)          5187
# Apple iPhone 8 (A1905)           4993
# Apple iPhone Xr (A2105)          4568
# Samsung Galaxy S8 (Sm-G950F)     4520
# Apple iPhone X (A1901)           3813
# Name: Handset Type, dtype: int64

# %%
plot = Visualization(top10handsets)
plot.draw_bar("Top ten handsets used by customers", "Manufacturer", "Count")

# %% [markdown]
# ## Top 3 handset manufacturers

# %%
top3man = df['Handset Manufacturer'].value_counts().head(3)
top3man
# Out:
# Apple      60137
# Samsung    40839
# Huawei     34423
# Name: Handset Manufacturer, dtype: int64

# %%
plot = Visualization(top3man)
plot.draw_bar("Top three manufacturers", "Manufacturer", "Count")

# %% [markdown]
# ## Top 5 handsets per top 3 handset manufacturer

# %%
top_manufacturers = df[df['Handset Manufacturer'].isin(['Apple','Samsung','Huawei'])]
handset = top_manufacturers.groupby('Handset Manufacturer')['Handset Type'].value_counts()
apple = handset.Apple[:5]
hwawei = handset.Huawei[:5]
samsung = handset.Samsung[:5]
print(apple)
print(samsung)
print(hwawei)
# Out:
# Handset Type
# Apple iPhone 6S (A1688)    9419
# Apple iPhone 6 (A1586)     9023
# Apple iPhone 7 (A1778)     6326
# Apple iPhone Se (A1723)    5187
# Apple iPhone 8 (A1905)     4993
# Name: Handset Type, dtype: int64
# Handset Type
# Samsung Galaxy S8 (Sm-G950F)    4520
# Samsung Galaxy A5 Sm-A520F      3724
# Samsung Galaxy J5 (Sm-J530)     3696
# Samsung Galaxy J3 (Sm-J330)     3484
# Samsung Galaxy S7 (Sm-G930X)    3199
# Name: Handset Type, dtype: int64
# Handset Type
# Huawei B528S-23A                  19752
# Huawei E5180                       2079
# Huawei P20 Lite Huawei Nova 3E     2021
# Huawei P20                         1480
# Huawei Y6 2018                      997
# Name: Handset Type, dtype: int64

# %%
plot = Visualization(apple)
plot.draw_bar("Apple", "Handset Type", "Count")
plot = Visualization(apple)
plot.draw_bar("Samsung", "Handset Type", "Count")
plot = Visualization(apple)
plot.draw_bar("Huawei", "Handset Type", "Count")

# %% [markdown]
# # Task 1.1

# %% [markdown]
# ## Number of xDR sessions
# First we should identify the property that identifies each user uniquely. Then we can count the aggregation of that property.

# %%
from scripts.utils import Utils
util = Utils()
xdr_sessions = util.find_agg(df, 'MSISDN/Number', 'count', 'Bearer Id', 10, False)
xdr_sessions
# Out:
#        MSISDN/Number  Bearer Id
# 13526   3.362632e+10       1084
# 13180   3.362578e+10         17
# 6437    3.361489e+10         17
# 37052   3.365973e+10         16
# 92923   3.376054e+10         15
# 76363   3.367588e+10         15
# 65118   3.366716e+10         13
# 13994   3.362708e+10         12
# 1279    3.360452e+10         12
# 92577   3.376041e+10         12

# %% [markdown]
# # Session Duration

# %%
session_duration = df.groupby('MSISDN/Number')['Dur. (ms)'].agg([sum])
session_duration = session_duration.sort_values('sum', ascending=False)
print(session_duration.head(20))
# Out:
#                       sum
# MSISDN/Number
# 3.362632e+10   81324722.0
# 3.362578e+10   18553754.0
# 3.361489e+10    9966898.0
# 3.376054e+10    9279434.0
# 3.366716e+10    8744914.0
# 3.366284e+10    6614270.0
# 3.366469e+10    6288730.0
# 3.360313e+10    6287761.0
# 3.366746e+10    5649882.0
# 3.376041e+10    5321667.0
# 3.365922e+10    5305958.0
# 3.360452e+10    5207990.0
# 3.369879e+10    5169128.0
# 3.366159e+10    4976479.0
# 3.365982e+10    4889926.0
# 3.367588e+10    4865947.0
# 3.369870e+10    4838428.0
# 3.362708e+10    4703516.0
# 3.366412e+10    4687441.0
# 3.366646e+10    4536757.0

# %% [markdown]
# # Total download (DL) and upload (UL) data

# %%
session_duration = df.groupby('MSISDN/Number')[['Total UL (Bytes)', 'Total DL (Bytes)']].sum()
session_duration['Total_data'] = session_duration['Total UL (Bytes)'] + session_duration['Total DL (Bytes)']
session_duration
# Out:
#                Total UL (Bytes)  Total DL (Bytes)    Total_data
# MSISDN/Number
# 3.360100e+10         36053108.0      8.426375e+08  8.786906e+08
# 3.360100e+10         36104459.0      1.207552e+08  1.568596e+08
# 3.360100e+10         39306820.0      5.566597e+08  5.959665e+08
# 3.360101e+10         20327526.0      4.019932e+08  4.223207e+08
# 3.360101e+10         94280527.0      1.363130e+09  1.457411e+09
# ...                         ...               ...           ...
# 3.379000e+10         26716429.0      6.879252e+08  7.146416e+08
# 3.379000e+10         35732243.0      4.445751e+08  4.803073e+08
# 3.197021e+12         37295915.0      1.948281e+08  2.321240e+08
# 3.370000e+14         56652839.0      5.396350e+08  5.962878e+08
# 8.823971e+14         60456049.0      7.869760e+07  1.391536e+08
#
# [106856 rows x 3 columns]

# %% [markdown]
# # Total data volume (in Bytes) during this session for each application

# %%
cols = df.columns.tolist()
i = cols.index('Social Media DL (Bytes)')

for j in range(i, len(cols) - 1, 2):
    title = cols[j].split(" ")[0] + "_data"
    df[title] = df[cols[j]] + df[cols[j + 1]]
df.columns
# Out:
# Index(['Bearer Id', 'Start', 'Start ms', 'End', 'End ms', 'Dur. (ms)', 'IMSI',
#        'MSISDN/Number', 'IMEI', 'Last Location Name', 'Avg RTT DL (ms)',
#        'Avg RTT UL (ms)', 'Avg Bearer TP DL (kbps)', 'Avg Bearer TP UL (kbps)',
#        'DL TP < 50 Kbps (%)', '50 Kbps < DL TP < 250 Kbps (%)',
#        '250 Kbps < DL TP < 1 Mbps (%)', 'DL TP > 1 Mbps (%)',
#        'UL TP < 10 Kbps (%)', '10 Kbps < UL TP < 50 Kbps (%)',
#        '50 Kbps < UL TP < 300 Kbps (%)', 'UL TP > 300 Kbps (%)',
#        'Activity Duration DL (ms)', 'Activity Duration UL (ms)', 'Dur. (ms).1',
#        'Handset Manufacturer', 'Handset Type', 'Nb of sec with Vol DL < 6250B',
#        'Nb of sec with Vol UL < 1250B', 'Social Media DL (Bytes)',
#        'Social Media UL (Bytes)', 'Google DL (Bytes)', 'Google UL (Bytes)',
#        'Email DL (Bytes)', 'Email UL (Bytes)', 'Youtube DL (Bytes)',
#        'Youtube UL (Bytes)', 'Netflix DL (Bytes)', 'Netflix UL (Bytes)',
#        'Gaming DL (Bytes)', 'Gaming UL (Bytes)', 'Other DL (Bytes)',
#        'Other UL (Bytes)', 'Total UL (Bytes)', 'Total DL (Bytes)',
#        'Social_data', 'Google_data', 'Email_data', 'Youtube_data',
#        'Netflix_data', 'Gaming_data', 'Other_data', 'Total_data'],
#       dtype='object')

# %%
du = DataUnderstanding(df)
du.pick_data(10)
# Out:
#       Bearer Id            Start  Start ms              End  End ms  \
# 0  1.311448e+19   4/4/2019 12:01     770.0  4/25/2019 14:35   662.0
# 1  1.311448e+19   4/9/2019 13:04     235.0   4/25/2019 8:15   606.0
# 2  1.311448e+19   4/9/2019 17:42       1.0  4/25/2019 11:58   652.0
# 3  1.311448e+19   4/10/2019 0:31     486.0   4/25/2019 7:36   171.0
# 4  1.311448e+19  4/12/2019 20:10     565.0  4/25/2019 10:40   954.0
# 5  1.311448e+19  4/12/2019 21:37     439.0   4/25/2019 8:08   553.0
# 6  1.311448e+19   4/13/2019 8:41     612.0   4/25/2019 8:16   168.0
# 7  1.304243e+19   4/14/2019 2:11     592.0   4/25/2019 2:26   512.0
# 8  1.311448e+19  4/14/2019 12:48     121.0  4/25/2019 10:22   960.0
# 9  1.304243e+19   4/15/2019 0:32       0.0   4/25/2019 0:40   284.0
#
#    Dur. (ms)          IMSI  MSISDN/Number          IMEI  \
# 0  1823652.0  2.082014e+14   3.366496e+10  3.552121e+13
# 1  1365104.0  2.082019e+14   3.368185e+10  3.579401e+13
# 2  1361762.0  2.082003e+14   3.376063e+10  3.528151e+13
# 3  1321509.0  2.082014e+14   3.375034e+10  3.535661e+13
# 4  1089009.0  2.082014e+14   3.369980e+10  3.540701e+13
# 5  1074638.0  2.082014e+14   3.366819e+10  3.529841e+13
# 6  1035261.0  2.082014e+14   3.366537e+10  8.676270e+13
# 7   951292.0  2.082010e+14   3.376349e+10  8.654640e+13
# 8   941634.0  2.082014e+14   3.369874e+10  3.556241e+13
# 9   864482.0  2.082003e+14   3.365922e+10  3.557311e+13
#
#       Last Location Name  ...  Total UL (Bytes)  Total DL (Bytes)  \
# 0  9.16456699548519E+015  ...        36749741.0       308879636.0
# 1                L77566A  ...        53800391.0       653384965.0
# 2                D42335A  ...        27883638.0       279807335.0
# 3                T21824A  ...        43324218.0       846028530.0
# 4                D88865A  ...        38542814.0       569138589.0
# 5                T89132C  ...        30307754.0       754452212.0
# 6  9.16456701058919E+015  ...        47925246.0        70562047.0
# 7   CELL_208_20_520025_1  ...        58813016.0       775350343.0
# 8                T42084A  ...        42363146.0       861612261.0
# 9                L20434C  ...        22417975.0       850570347.0
#
#    Social_data  Google_data  Email_data  Youtube_data  Netflix_data  \
# 0    1570185.0    2905912.0   3701304.0    18355943.0    17855187.0
# 1    1933278.0    4414096.0    937385.0    39359124.0    35565545.0
# 2    1726277.0   10229119.0   3363124.0    34425237.0    23751202.0
# 3     657493.0   11811761.0   2070983.0    36534765.0    15092588.0
# 4     912788.0    7748843.0   2110349.0    34222253.0    17539799.0
# 5    3200014.0   12934133.0   2902410.0    23944031.0    13881809.0
# 6    1624991.0    4906872.0   2090979.0     9120760.0    31212766.0
# 7    3161403.0    3872713.0   3500104.0    31924969.0    18933702.0
# 8     372625.0    8902099.0   3380069.0    29297508.0    19054441.0
# 9    1585413.0    8778341.0    766046.0    22911539.0    13185350.0
#
#    Gaming_data   Other_data   Total_data
# 0  292426453.0  180558843.0  345629377.0
# 1  609920783.0  541959383.0  707185356.0
# 2  229980251.0  414908351.0  307690973.0
# 3  810387875.0  761837216.0  889352748.0
# 4  531237049.0  564619822.0  607681403.0
# 5  723461512.0  659414334.0  784759966.0
# 6   58881157.0  814303325.0  118487293.0
# 7  765055811.0  545316477.0  834163359.0
# 8  828219634.0  187669517.0  903975407.0
# 9  812946425.0   77671250.0  872988322.0
#
# [10 rows x 53 columns]

# %%
util.save_data(df, '../data/clean_data.csv')

# %% [markdown]
# ## Analyze the basic metrics
