# %%
import sys, os
sys.path.append(os.path.abspath(os.path.join('..')))

# %%
#import our dataloader
from scripts.dataloader import DataLoader

# %%
dirname = '../data'
filename = 'data.csv'
dl = DataLoader(dirname, filename)

# %% [markdown]
# # Read the dataset

# %%
df = dl.read_csv()

# %% [markdown]
# # Data Understanding

# %%
from scripts.data_understanding import DataUnderstanding
du = DataUnderstanding(df)
du.pick_data(20)
# Out:
#        Bearer Id            Start  Start ms              End  End ms  \
# 0   1.311448e+19   4/4/2019 12:01     770.0  4/25/2019 14:35   662.0
# 1   1.311448e+19   4/9/2019 13:04     235.0   4/25/2019 8:15   606.0
# 2   1.311448e+19   4/9/2019 17:42       1.0  4/25/2019 11:58   652.0
# 3   1.311448e+19   4/10/2019 0:31     486.0   4/25/2019 7:36   171.0
# 4   1.311448e+19  4/12/2019 20:10     565.0  4/25/2019 10:40   954.0
# 5   1.311448e+19  4/12/2019 21:37     439.0   4/25/2019 8:08   553.0
# 6   1.311448e+19   4/13/2019 8:41     612.0   4/25/2019 8:16   168.0
# 7   1.304243e+19   4/14/2019 2:11     592.0   4/25/2019 2:26   512.0
# 8   1.311448e+19  4/14/2019 12:48     121.0  4/25/2019 10:22   960.0
# 9   1.304243e+19   4/15/2019 0:32       0.0   4/25/2019 0:40   284.0
# 10  7.277826e+18  4/15/2019 10:30      90.0   4/25/2019 6:14   775.0
# 11  1.311448e+19  4/15/2019 11:33     626.0  4/25/2019 18:44   542.0
# 12  1.311448e+19  4/15/2019 12:20     729.0   4/25/2019 8:40   862.0
# ...

# %%
#Dimension of data
du.data_dimension()
# Out:
# (150001, 55)

# %%
#Datatypes of columns
du.get_datatypes()
# Out:
# Bearer Id                                   float64
# Start                                        object
# Start ms                                    float64
# End                                          object
# End ms                                      float64
# Dur. (ms)                                   float64
# IMSI                                        float64
# MSISDN/Number                               float64
# IMEI                                        float64
# Last Location Name                           object
# Avg RTT DL (ms)                             float64
# Avg RTT UL (ms)                             float64
# Avg Bearer TP DL (kbps)                     float64
# Avg Bearer TP UL (kbps)                     float64
# TCP DL Retrans. Vol (Bytes)                 float64
# TCP UL Retrans. Vol (Bytes)                 float64
# DL TP < 50 Kbps (%)                         float64
# 50 Kbps < DL TP < 250 Kbps (%)              float64
# ...

# %% [markdown]
# # Skew of Univariate Distributions
# Skew refers to a distribution that is assumed Gaussian (normal or bell curve) that is shifted or
# squashed in one direction or another. The skew result show a positive (right) or negative (left) skew. Values closer to zero show less skew.

# %%
# Get skew of univarian data distribution
du.get_skew()
# Out:
# Bearer Id                                     0.026666
# Start ms                                      0.000968
# End ms                                       -0.001163
# Dur. (ms)                                     3.952609
# IMSI                                         41.045956
# MSISDN/Number                               332.155856
# IMEI                                          1.071470
# Avg RTT DL (ms)                              62.907828
# Avg RTT UL (ms)                              28.457415
# Avg Bearer TP DL (kbps)                       2.589437
# Avg Bearer TP UL (kbps)                       4.503413
# TCP DL Retrans. Vol (Bytes)                  15.951809
# TCP UL Retrans. Vol (Bytes)                  84.113393
# DL TP < 50 Kbps (%)                          -2.297803
# 50 Kbps < DL TP < 250 Kbps (%)                3.271453
# 250 Kbps < DL TP < 1 Mbps (%)                 4.566158
# DL TP > 1 Mbps (%)                            5.370351
# ...

# %% [markdown]
# # Correlation of Attributes
# Correlation refers to the relationship between two variables and how they may or may notchange together.

# %%
du.attributes_correlation()
# Out:
#                                           Bearer Id  Start ms    End ms  \
# Bearer Id                                  1.000000  0.002961 -0.001219
# Start ms                                   0.002961  1.000000  0.120945
# End ms                                    -0.001219  0.120945  1.000000
# Dur. (ms)                                  0.007515  0.001287 -0.001302
# IMSI                                       0.000152 -0.000054  0.000328
# MSISDN/Number                             -0.003307 -0.001021 -0.001890
# IMEI                                       0.164054 -0.001133 -0.000032
# Avg RTT DL (ms)                           -0.022561  0.004141 -0.005287
# Avg RTT UL (ms)                            0.034924 -0.002221 -0.002607
# Avg Bearer TP DL (kbps)                    0.063973 -0.000690  0.000694
# Avg Bearer TP UL (kbps)                    0.048123 -0.001268  0.000687
# TCP DL Retrans. Vol (Bytes)                0.019186  0.000328  0.004941
# ...

# %% [markdown]
# # Descriptive Statstics
# Descriptive statistics can give you great insight into the shape of each attribute. Often you can
# create more summaries than you have time to review. The describe() function on the Pandas
# DataFrame lists 8 statistical properties of each attribute. They are count, mean, standard deviation, 25th Percentile, Median, 75th Percentile, and max.

# %%
du.get_descriptive_stat()
# Out:
#           Bearer Id       Start ms         End ms     Dur. (ms)          IMSI  \
# count  1.490100e+05  150000.000000  150000.000000  1.500000e+05  1.494310e+05
# mean   1.013887e+19     499.188200     498.800880  1.046086e+05  2.082016e+14
# std    2.893173e+18     288.611834     288.097653  8.103762e+04  2.148809e+10
# min    6.917538e+18       0.000000       0.000000  7.142000e+03  2.040471e+14
# 25%    7.349883e+18     250.000000     251.000000  5.744050e+04  2.082014e+14
# 50%    7.349883e+18     499.000000     500.000000  8.639900e+04  2.082015e+14
# 75%    1.304243e+19     749.000000     750.000000  1.324302e+05  2.082018e+14
# max    1.318654e+19     999.000000     999.000000  1.859336e+06  2.140743e+14
#
#        MSISDN/Number          IMEI  Avg RTT DL (ms)  Avg RTT UL (ms)  \
# count   1.489350e+05  1.494290e+05    122172.000000    122189.000000
# mean    4.188282e+10  4.847455e+13       109.795706        17.662883
# ...

# %% [markdown]
# # Visualization

# %%
from scripts.visualization import Visualization

# %% [markdown]
# # Histogram

# %%
disp = Visualization(df['Total UL (Bytes)'])
disp.draw_hist()

# %%
disp = Visualization(df['Total DL (Bytes)'])
disp.draw_hist()

# %% [markdown]
# # Density Plot

# %%
disp = Visualization(df[['Total UL (Bytes)', 'Total DL (Bytes)']])
disp.draw_density_plot((2,1))

# %% [markdown]
# # Box and Whisker Plots

# %%
disp.draw_box_plots()

# %% [markdown]
# # Multivariant Plots

# %% [markdown]
# ## Correlation Matrix Plot

# %%
disp = Visualization(df)
disp.draw_correlation_matrix()

# %% [markdown]
# ## Scatter Plot Matrix

# %%
disp = Visualization(df[['Total UL (Bytes)', 'Total DL (Bytes)', 'Social Media UL (Bytes)']])
disp.draw_scatter()
# Out:
# /home/hmicheal/.conda/envs/10x/lib/python3.10/site-packages/IPython/core/pylabtools.py:151: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)
